# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Dataset.csv')

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
#        occupation  relationship   race  gender  capital-gain  capital-loss  \
# 0           False         False  False   False         False         False
# 1           False         False  False   False         False         False
# 2           False         False  False   False         False         False
# 3           False         False  False   False         False         False
# 4           False         False  False   False         False         False
# ...           ...           ...    ...     ...           ...           ...
# 48837       False         False  False   False         False         False
# 48838       False         False  False   False         False         False
# 48839       False         False  False   False         False         False
# 48840       False         False  False   False         False         False
# 48841       False         False  False   False         False         False
#
#        hours-per-week  native-country  income
# 0               False           False   False
# 1               False           False   False
# 2               False           False   False
# 3               False           False   False
# 4               False           False   False
# ...               ...             ...     ...
# 48837           False           False   False
# 48838           False           False   False
# 48839           False           False   False
# 48840           False           False   False
# 48841           False           False   False
#
# [48842 rows x 15 columns]

# %%
df.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df.gender.value_counts()
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
df.education.value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df.occupation.replace({'?':"Others"} ,inplace=True)
# Out:
# /tmp/ipython-input-92-1897620337.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.occupation.replace({'?':"Others"} ,inplace=True)

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

data = df # Assuming 'data' was intended to be 'df'
plt.boxplot(data['age'])
plt.show()

# %%
df=df[(df['age']<=75) & (df['age']>=17)]

# %%
df.workclass.replace({'?':'Not Listed'},inplace=True)
# Out:
# /tmp/ipython-input-96-230732010.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.workclass.replace({'?':'Not Listed'},inplace=True)
# /tmp/ipython-input-96-230732010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.workclass.replace({'?':'Not Listed'},inplace=True)

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             33756
# Self-emp-not-inc     3796
# Local-gov            3110
# Not Listed           2700
# State-gov            1979
# Self-emp-inc         1669
# Federal-gov          1428
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df=df[df['workclass']!='Without-pay']

# %%
df=df[df['workclass']!='Never-worked']

# %%
df=df[df['education']!='5th-6th']
df=df[df['education']!='1st-4th']
df=df[df['education']!='Preschool']

# %%
df.drop('education',axis=1,inplace=True)

# %%
df=df[ (df['age']<=75)& (df['age']>=17)]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

df['workclass']=encoder.fit_transform(df['workclass'])

df['marital-status']=encoder.fit_transform(df['marital-status'])
df['occupation']=encoder.fit_transform(df['occupation'])
df['relationship']=encoder.fit_transform(df['relationship'])
df['race']=encoder.fit_transform(df['race'])
df['gender']=encoder.fit_transform(df['gender'])
df['native-country']=encoder.fit_transform(df['native-country'])

# %%
X=df.drop(columns=['income'])
y=df['income']

# %%
X
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 4       18          2  103497               10               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48840   22          3  201490                9               4           0
# 48841   52          4  287927                9               2           3
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 0                 3     2       1             0             0              40
# 1                 0     4       1             0             0              50
# 2                 0     4       1             0             0              40
# 3                 0     2       1          7688             0              40
# 4                 3     4       0             0             0              30
# ...             ...   ...     ...           ...           ...             ...
# 48837             5     4       0             0             0              38
# 48838             0     4       1             0             0              40
# 48839             4     4       0             0             0              40
# 48840             3     4       1             0             0              20
# 48841             5     4       0         15024             0              40
#
#        native-country
# 0                  39
# 1                  39
# 2                  39
# 3                  39
# 4                  39
# ...               ...
# 48837              39
# 48838              39
# 48839              39
# 48840              39
# 48841              39
#
# [47619 rows x 13 columns]

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 47619, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X=scaler.fit_transform(X)
X
# Out:
# array([[0.13793103, 0.5       , 0.14512876, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.36206897, 0.5       , 0.05245126, ..., 0.        , 0.5       ,
#         0.95121951],
#        [0.18965517, 0.16666667, 0.21964867, ..., 0.        , 0.39795918,
#         0.95121951],
#        ...,
#        [0.70689655, 0.5       , 0.09446153, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.0862069 , 0.5       , 0.12800425, ..., 0.        , 0.19387755,
#         0.95121951],
#        [0.60344828, 0.66666667, 0.18648211, ..., 0.        , 0.39795918,
#         0.95121951]])

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=23,stratify=y)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
predict=knn.predict(X_test)
predict
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predict)
# Out:
# 0.8167786644267114

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
predict=dt.predict(X_test)
predict
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predict)
# Out:
# 0.8063838723225536

# %% [markdown]
# # ANN

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.models import Sequential
from keras.layers import Dense

# Define the ANN model
model = Sequential()

# Add input layer and first hidden layer
# The number of input dimensions is the number of columns in X_train
model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))

# Add a second hidden layer
model.add(Dense(units=32, activation='relu'))

# Add the output layer
# For binary classification, use 1 unit and sigmoid activation
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,009 (11.75 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Convert target variable to numerical if it's not already
# Assuming y_train contains string labels like '<=50K' and '>50K'
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(y_train)
y_test_encoded = encoder.transform(y_test)


# Train the model
history = model.fit(X_train, y_train_encoded, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7697 - loss: 0.4735 - val_accuracy: 0.8282 - val_loss: 0.3629
# Epoch 2/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8368 - loss: 0.3508 - val_accuracy: 0.8355 - val_loss: 0.3395
# Epoch 3/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8439 - loss: 0.3330 - val_accuracy: 0.8451 - val_loss: 0.3330
# Epoch 4/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8417 - loss: 0.3370 - val_accuracy: 0.8460 - val_loss: 0.3293
# Epoch 5/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8438 - loss: 0.3289 - val_accuracy: 0.8442 - val_loss: 0.3319
# Epoch 6/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8395 - loss: 0.3379 - val_accuracy: 0.8447 - val_loss: 0.3268
# Epoch 7/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8462 - loss: 0.3296 - val_accuracy: 0.8459 - val_loss: 0.3261
# Epoch 8/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8477 - loss: 0.3284 - val_accuracy: 0.8463 - val_loss: 0.3264
# Epoch 9/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8476 - loss: 0.3273 - val_accuracy: 0.8454 - val_loss: 0.3283
# Epoch 10/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8483 - loss: 0.3223 - val_accuracy: 0.8443 - val_loss: 0.3286
# Epoch 11/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8477 - loss: 0.3236 - val_accuracy: 0.8468 - val_loss: 0.3261
# Epoch 12/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8504 - loss: 0.3212 - val_accuracy: 0.8439 - val_loss: 0.3277
# Epoch 13/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8481 - loss: 0.3238 - val_accuracy: 0.8466 - val_loss: 0.3247
# Epoch 14/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8460 - loss: 0.3244 - val_accuracy: 0.8463 - val_loss: 0.3270
# Epoch 15/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8471 - loss: 0.3204 - val_accuracy: 0.8470 - val_loss: 0.3247
# Epoch 16/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8500 - loss: 0.3203 - val_accuracy: 0.8498 - val_loss: 0.3233
# Epoch 17/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8485 - loss: 0.3202 - val_accuracy: 0.8472 - val_loss: 0.3239
# Epoch 18/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8488 - loss: 0.3202 - val_accuracy: 0.8455 - val_loss: 0.3290
# Epoch 19/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8509 - loss: 0.3172 - val_accuracy: 0.8487 - val_loss: 0.3251
# Epoch 20/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8525 - loss: 0.3133 - val_accuracy: 0.8421 - val_loss: 0.3289
# Epoch 21/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8519 - loss: 0.3181 - val_accuracy: 0.8430 - val_loss: 0.3377
# Epoch 22/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8460 - loss: 0.3244 - val_accuracy: 0.8491 - val_loss: 0.3219
# Epoch 23/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8525 - loss: 0.3127 - val_accuracy: 0.8495 - val_loss: 0.3224
# Epoch 24/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8492 - loss: 0.3186 - val_accuracy: 0.8480 - val_loss: 0.3226
# Epoch 25/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8513 - loss: 0.3171 - val_accuracy: 0.8512 - val_loss: 0.3232
# Epoch 26/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8515 - loss: 0.3175 - val_accuracy: 0.8508 - val_loss: 0.3231
# Epoch 27/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8533 - loss: 0.3167 - val_accuracy: 0.8483 - val_loss: 0.3237
# Epoch 28/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8548 - loss: 0.3107 - val_accuracy: 0.8513 - val_loss: 0.3202
# Epoch 29/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8552 - loss: 0.3070 - val_accuracy: 0.8460 - val_loss: 0.3277
# Epoch 30/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8517 - loss: 0.3142 - val_accuracy: 0.8506 - val_loss: 0.3220
# Epoch 31/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8540 - loss: 0.3153 - val_accuracy: 0.8467 - val_loss: 0.3214
# Epoch 32/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8521 - loss: 0.3151 - val_accuracy: 0.8443 - val_loss: 0.3334
# Epoch 33/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8540 - loss: 0.3121 - val_accuracy: 0.8498 - val_loss: 0.3201
# Epoch 34/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8544 - loss: 0.3122 - val_accuracy: 0.8506 - val_loss: 0.3198
# Epoch 35/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8546 - loss: 0.3115 - val_accuracy: 0.8492 - val_loss: 0.3221
# Epoch 36/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8524 - loss: 0.3162 - val_accuracy: 0.8500 - val_loss: 0.3199
# Epoch 37/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8568 - loss: 0.3109 - val_accuracy: 0.8512 - val_loss: 0.3171
# Epoch 38/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8531 - loss: 0.3070 - val_accuracy: 0.8504 - val_loss: 0.3225
# Epoch 39/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8539 - loss: 0.3142 - val_accuracy: 0.8509 - val_loss: 0.3183
# Epoch 40/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8527 - loss: 0.3134 - val_accuracy: 0.8530 - val_loss: 0.3169
# Epoch 41/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8554 - loss: 0.3094 - val_accuracy: 0.8514 - val_loss: 0.3193
# Epoch 42/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8579 - loss: 0.3047 - val_accuracy: 0.8471 - val_loss: 0.3213
# Epoch 43/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8545 - loss: 0.3090 - val_accuracy: 0.8463 - val_loss: 0.3226
# Epoch 44/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8546 - loss: 0.3052 - val_accuracy: 0.8453 - val_loss: 0.3242
# Epoch 45/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8542 - loss: 0.3119 - val_accuracy: 0.8500 - val_loss: 0.3187
# Epoch 46/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8557 - loss: 0.3090 - val_accuracy: 0.8505 - val_loss: 0.3172
# Epoch 47/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8563 - loss: 0.3087 - val_accuracy: 0.8470 - val_loss: 0.3268
# Epoch 48/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8523 - loss: 0.3128 - val_accuracy: 0.8476 - val_loss: 0.3202
# Epoch 49/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8557 - loss: 0.3101 - val_accuracy: 0.8472 - val_loss: 0.3220
# Epoch 50/50
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8578 - loss: 0.3055 - val_accuracy: 0.8510 - val_loss: 0.3187

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test_encoded)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8371 - loss: 0.3385
# Test Loss: 0.3341
# Test Accuracy: 0.8423

# %%
import pickle

# Save the model in .pkl format (not recommended for Keras models)
try:
    with open('mlp_model.pkl', 'wb') as file:
        pickle.dump(model, file)
    print("Model saved successfully in mlp_model.pkl (using pickle, not recommended for Keras).")
except Exception as e:
    print(f"An error occurred while pickling the model: {e}")
# Out:
# Model saved successfully in mlp_model.pkl (using pickle, not recommended for Keras).

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import joblib

# Load the trained model
model = joblib.load("mlp_model.pkl")

st.set_page_config(page_title="Employee Salary Classification", page_icon="💼", layout="centered")

st.title("💼 Employee Salary Classification App")
st.markdown("Predict whether an employee earns >50K or ≤50K based on input features.")

# Sidebar inputs (these must match your training feature columns)
st.sidebar.header("Input Employee Details")

# ✨ Replace these fields with your dataset's actual input columns
age = st.sidebar.slider("Age", 18, 65, 30)
education = st.sidebar.selectbox("Education Level", [
    "Bachelors", "Masters", "PhD", "HS-grad", "Assoc", "Some-college"
])
occupation = st.sidebar.selectbox("Job Role", [
    "Tech-support", "Craft-repair", "Other-service", "Sales",
    "Exec-managerial", "Prof-specialty", "Handlers-cleaners", "Machine-op-inspct",
    "Adm-clerical", "Farming-fishing", "Transport-moving", "Priv-house-serv",
    "Protective-serv", "Armed-Forces"
])
hours_per_week = st.sidebar.slider("Hours per week", 1, 80, 40)
experience = st.sidebar.slider("Years of Experience", 0, 40, 5)

# Build input DataFrame (⚠️ must match preprocessing of your training data)
input_df = pd.DataFrame({
    'age': [age],
    'education': [education],
    'occupation': [occupation],
    'hours-per-week': [hours_per_week],
    'experience': [experience]
})

st.write("### 🔎 Input Data")
st.write(input_df)

# Predict button
if st.button("Predict Salary Class"):
    prediction = model.predict(input_df)
    st.success(f"✅ Prediction: {prediction[0]}")

# Batch prediction
st.markdown("---")
st.markdown("#### 📂 Batch Prediction")
uploaded_file = st.file_uploader("Upload a CSV file for batch prediction", type="csv")

if uploaded_file is not None:
    batch_data = pd.read_csv(uploaded_file)
    st.write("Uploaded data preview:", batch_data.head())
    batch_preds = model.predict(batch_data)
    batch_data['PredictedClass'] = batch_preds
    st.write("✅ Predictions:")
    st.write(batch_data.head())
    csv = batch_data.to_csv(index=False).encode('utf-8')
    st.download_button("Download Predictions CSV", csv, file_name='predicted_classes.csv', mime='text/csv')
# Out:
# Writing app.py

# %%
# !streamlit run app.py
# Out:
# /bin/bash: line 1: streamlit: command not found
